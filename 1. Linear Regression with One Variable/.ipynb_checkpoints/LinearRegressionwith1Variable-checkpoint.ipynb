# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns
# %matplotlib inline

# %%
print(sns.__version__)
print(pd.__version__)
# Out:
# 0.9.0
# 0.23.4

# %%
data = pd.read_csv("../kc_house_data.csv")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# Correlation

# %%
# Create a correlation matrix
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns;

# %%
sns.pairplot(data=data)

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# Create a simple Linear regression model with one variable of sqft_living to price

# %% [markdown]
# First Check the scatter plot of sqft living to price

# %%
data.plot(kind='scatter', x='sqft_living', y='price', figsize=(12,8))

# %% [markdown]
# Comment on relationship between these 2 variables. Does it look Linear? Try to fit the line on the data

# %% [markdown]
# Split data into training and testing. training data is used for training our model while test data will be used to see how our model works. In Machine Learning, we divide the dataset into 3 parts : training dataset, validation dataset and testing dataset. We will talk about validation dataset later on, right now we are only splitting our dataset into training and testing.

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data = train_test_split(data[['sqft_living','price']], test_size = 0.2,random_state=0)

# %%
print("train: ",train_data.shape)
print("test: ",test_data.shape)
# Out:
# train:  (17290, 2)
# test:  (4323, 2)

# %% [markdown]
# Convert to numpy array

# %%
Xtrain=np.array(train_data['sqft_living'])
Ytrain=np.array(train_data['price'])

Xtest=np.array(test_data['sqft_living'])
Ytest=np.array(test_data['price'])

# %%
Xtrain.shape
# Out:
# (17290,)

# %% [markdown]
# Add dimensions

# %%
Xtrain=np.expand_dims(Xtrain, axis=1)
Xtest=np.expand_dims(Xtest, axis=1)

Ytrain=np.expand_dims(Ytrain,axis=1)
Ytest=np.expand_dims(Ytest,axis=1)

# %%
Ytrain.shape
# Out:
# (17290, 1)

# %%
Xtrain=np.c_[np.ones(Xtrain.shape[0]),Xtrain ]  
Xtest=np.c_[np.ones(Xtest.shape[0]),Xtest ]

# %% [markdown]
# Check Shapes

# %%
print("Xtrain: ",Xtrain.shape)
print("Ytrain: ",Ytrain.shape)

print("Xtest: ",Xtest.shape)
print("Ytest: ",Ytest.shape)
# Out:
# Xtrain:  (17290, 2)
# Ytrain:  (17290, 1)
# Xtest:  (4323, 2)
# Ytest:  (4323, 1)

# %%
Xtrain
# Out:
# array([[1.00e+00, 1.57e+03],
#        [1.00e+00, 1.78e+03],
#        [1.00e+00, 1.09e+03],
#        ...,
#        [1.00e+00, 2.36e+03],
#        [1.00e+00, 2.37e+03],
#        [1.00e+00, 2.38e+03]])

# %% [markdown]
# #### Hypothesis

# %%
def hypothesis(X,theta):
    hyp=np.dot(X,theta)
    return hyp

# %% [markdown]
# #### Cost/Error Function

# %%
def Cost(X, Y,  theta):
    N = Y.size
    cost = 0.0
    hyp=hypothesis(X,theta)
    cost = (1/(2*float(N)))*(np.sum(np.square(Y-hyp)))
    return(cost)

# %% [markdown]
# #### Gradient Descent

# %%
def GradientDescent(X, Y, theta, alpha=0.0000001, num_iters=20):
    N = Y.size
    history = np.zeros(num_iters)
    for i in np.arange(num_iters):
        h = hypothesis(X,theta)
        theta = theta - alpha * ( (-1/float(N)) * (X.T.dot(Y-h)) )
        history[i] = Cost(X, Y, theta)
    return(theta, history)

# %%
theta=np.expand_dims(np.random.randn(2),axis=1)

# %%
theta.shape
# Out:
# (2, 1)

# %% [markdown]
# Lets check error with random theta

# %%
Cost(Xtrain,Ytrain,theta)
# Out:
# 218303241835.68277

# %% [markdown]
# Check with random theta how it fits the line

# %%
x = np.linspace(train_data.sqft_living.min(), train_data.sqft_living.max(), 100)
f = theta[0, 0] + (theta[1, 0] * x)

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(train_data.sqft_living, train_data.price, label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('Sqft Living')
ax.set_ylabel('Pice')
ax.set_title('Predicted Pice vs. Sqft Living')
# Out:
# Text(0.5,1,'Predicted Pice vs. Sqft Living')

# %%
print(Xtrain.shape)
# Out:
# (17290, 2)

# %%
theta , Cost_E = GradientDescent(Xtrain, Ytrain,theta)
print('theta: ',theta.ravel())

plt.plot(Cost_E)
plt.ylabel('Cost E')
plt.xlabel('Iterations');
# Out:
# theta:  [ -0.34520232 264.59532804]

# %%
print(theta)
# Out:
# [[ -0.34520232]
#  [264.59532804]]

# %%
x = np.linspace(train_data.sqft_living.min(), train_data.sqft_living.max(), 100)
f = theta[0, 0] + (theta[1, 0] * x)

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(train_data.sqft_living, train_data.price, label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('Sqft Living')
ax.set_ylabel('Pice')
ax.set_title('Predicted Pice vs. Sqft Living')
# Out:
# Text(0.5,1,'Predicted Pice vs. Sqft Living')

# %% [markdown]
# Lets see how it performs on test unseen dataset

# %% [markdown]
# These are original prices

# %% [markdown]
# Ytrain, Ytest

# %%
print(Ytest)
# Out:
# [[ 297000.]
#  [1578000.]
#  [ 562100.]
#  ...
#  [ 369950.]
#  [ 300000.]
#  [ 575950.]]

# %%
YPredicted=hypothesis(Xtest,theta)

# %%
print(YPredicted)
# Out:
# [[ 378370.80715353]
#  [1235660.18191648]
#  [ 381016.76201391]
#  ...
#  [ 359849.12313087]
#  [ 251364.97385531]
#  [ 433935.8592215 ]]

# %%
test_data.shape
# Out:
# (4323, 2)

# %%
x = np.linspace(test_data.sqft_living.min(), test_data.sqft_living.max(), 100)
f = theta[0, 0] + (theta[1, 0] * x)

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(test_data.sqft_living, test_data.price, label='Test Data')
ax.legend(loc=2)
ax.set_xlabel('Sqft Living')
ax.set_ylabel('Pice')
ax.set_title('Predicted Pice vs. Sqft Living')
# Out:
# Text(0.5,1,'Predicted Pice vs. Sqft Living')

# %% [markdown]
# We can evaluate using Sum of squared error or Root mean Squared error or any other type of error

# %% [markdown]
# We can instead use builtin library of sklearn that does everything for us. We can simply call function and pass in data. Lets see sklearn Linear Regression Model

# %%
from sklearn.linear_model import SGDRegressor

# %%
Xtrain=np.expand_dims(np.array(train_data['sqft_living']),axis=1)
Ytrain=np.array(train_data['price'])
                
Xtest=np.expand_dims(np.array(test_data['sqft_living']),axis=1)
Ytest=np.array(test_data['price'])

# %%
print(Xtrain.shape)
print(Ytrain.shape)

print(Xtest.shape)
print(Ytest.shape)
# Out:
# (17290, 1)
# (17290,)
# (4323, 1)
# (4323,)

# %%
model = SGDRegressor(n_iter=20,eta0=0.0000001,verbose=1)
model.fit(Xtrain, Ytrain)
# Out:
# -- Epoch 1
# Norm: 285.30, NNZs: 1, Bias: -1.709815, T: 17290, Avg. loss: 39299433000.928337
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 297.25, NNZs: 1, Bias: -2.818308, T: 34580, Avg. loss: 37927392889.275360
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 246.57, NNZs: 1, Bias: -3.770377, T: 51870, Avg. loss: 37677315520.960022
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 258.66, NNZs: 1, Bias: -4.596138, T: 69160, Avg. loss: 37126403319.530167
# Total training time: 0.01 seconds.
# -- Epoch 5
# Norm: 308.65, NNZs: 1, Bias: -5.391502, T: 86450, Avg. loss: 37057891712.708900
# Total training time: 0.01 seconds.
# -- Epoch 6
# Norm: 249.35, NNZs: 1, Bias: -6.195212, T: 103740, Avg. loss: 37184121775.957169
# Total training time: 0.01 seconds.
# -- Epoch 7
# Norm: 294.29, NNZs: 1, Bias: -6.906122, T: 121030, Avg. loss: 37060642484.447166
# Total training time: 0.01 seconds.
# -- Epoch 8
# ...

# %% [markdown]
# Like error function, here we have builtin function named mean_squared_error

# %%
from sklearn.metrics import mean_squared_error

# %%
predictions = model.predict(Xtrain)
error= mean_squared_error(Ytrain.squeeze(), predictions)
print(np.sqrt(error) )
# Out:
# 266236.9024290873

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.array(Xtest[:, 0])
f = model.predict(Xtest).flatten()

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(test_data.sqft_living, test_data.price, label='Test Data')
ax.legend(loc=2)
